# %%
from pathlib import Path
import pandas as pd

# change this to your folder path
FOLDER = Path("/home/mayna/fss/data/parsed")

# loop over all csv files in the folder
for csv_file in FOLDER.glob("*.csv"):
    print("\n" + "=" * 80)
    print(f"File: {csv_file.name}")
    print("=" * 80)
    
    try:
        df = pd.read_csv(csv_file)
        print(df.head())
    except Exception as e:
        print(f"Error reading {csv_file.name}: {e}")
# Out:
# ================================================================================
# File: matieres.csv
# ================================================================================
#   id_mat            nom_mat       nom_module semestre
# 0    i01          algo.num1  Mathématiques 5       S1
# 1    i02  opt prog lineaire  Mathématiques 5       S1
# 2    i03        prog java 2  Développement 5       S1
# 3    i04           test log  Développement 5       S1
# 4    i05              agile  Développement 5       S1
#
# ================================================================================
# File: notes.csv
# ================================================================================
#            id  promo id_mat  mg_mat  mg_module
# 0  02d62872c6      2    i01   16.50      17.60
# 1  02d62872c6      2    i02   18.70      17.60
# 2  02d62872c6      2    i03   12.60      13.76
# 3  02d62872c6      2    i04   14.90      13.76
# 4  02d62872c6      2    i05   13.79      13.76
#
# ================================================================================
# File: parcours.csv
# ================================================================================
#            id  promo  moy_s1  moy_s2  moy_ann  rang passage
# 0  02d62872c6      2   15.22   15.84    15.53   2.0   Admis
# 1  033574f04c      2   13.52   14.52    14.02   8.0   Admis
# 2  033b92fdb6      3   11.97   12.56    12.27  22.0   Admis
# 3  06ab8aee6d      3   12.59   12.67    12.63  17.0   Admis
# 4  0af7383ac5      3   11.79   13.32    12.56  21.0   Admis
#
# ================================================================================
# File: mapping_id_noms.csv
# ================================================================================
#       id_anon        Nom     Prénom  Promotion
# 0  a467c6574a       ABID    OUSSEMA          1
# 1  5e305db688      ALIMI    MOHAMED          1
# 2  fe746363c4    ALOULOU       HEDI          1
# 3  0b01093cfa      AMINE    HENTATI          1
# 4  afaf20ddb8  BARGOUGUI  MONTASSAR          1
#
# ================================================================================
# File: profils_anonymes.csv
# ================================================================================
#       id_anon  Promotion Genre origine Licence/ Pisi      Bac
# 0  a467c6574a          1     m    sfax          pisi  science
# 1  5e305db688          1     m    sfax          pisi     math
# 2  fe746363c4          1     m    sfax          pisi     math
# 3  0b01093cfa          1     m    sfax          pisi  science
# 4  afaf20ddb8          1     m    sfax          pisi     math
